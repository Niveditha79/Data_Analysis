# %% [markdown]
# #### Goal:
#
# ### Explore the Mall Customers dataset, clean the data, perform customer segmentation analysis, and visualize insights using NumPy, Pandas, Matplotlib, and Seaborn.
#
# ## 1. Why This Project?
# 1. Learn data preprocessing and handling missing values using Pandas.
# 2. Use NumPy for basic statistical analysis (mean, standard deviation, etc.).
# 3. Visualize customer demographics and behavior using Matplotlib and Seaborn.
# 4. Understand customer segments based on Age, Income, and Spending Score, useful for marketing strategy.

# %% [markdown]
# ### 2. Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 3. Load Dataset

# %%
# Load dataset
df = pd.read_csv('Mall_Customers.csv')

# Display first 5 rows
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# ### Explore Data

# %%
print("Shape:", df.shape)
print(df.info())
print(df.isnull().sum())
print(df.describe())
# Out:
# Shape: (200, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# ...

# %% [markdown]
# #### Insights
# Balanced Dataset: There are 200 customers with no missing values in any column.
#
# Age Range: Customers range from 18 to 70 years old, with an average age of about 39.
#
# Income Levels Vary: Annual income ranges from $15k to $137k, showing a wide income spread.
#
# Spending Behavior: Spending scores range from 1 to 99, indicating diverse shopping habits across customers.

# %% [markdown]
# ## 5.Data Cleaning

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('Mall_Customers.csv')  # Adjust path as needed

# 1. Check for missing values
print(df.isnull().sum())

duplicates = df.duplicated().sum()
print(f'Duplicates: {duplicates}')
# If duplicates exist, remove them
df = df.drop_duplicates()

# 4. Verify data types
print(df.dtypes)

df.rename(columns={
    'Annual Income (k$)': 'Annual_Income',
    'Spending Score (1-100)': 'Spending_Score'
}, inplace=True)


df = df[(df['Age'] >= 18) & (df['Age'] <= 70)]

# Final shape and info
print(df.shape)
print(df.info())
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64
# Duplicates: 0
# CustomerID                 int64
# Genre                     object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object
# (200, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      200 non-null    int64
#  1   Genre           200 non-null    object
#  2   Age             200 non-null    int64
#  3   Annual_Income   200 non-null    int64
#  4   Spending_Score  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None

# %% [markdown]
# #### Insights
#
# No missing values or duplicates in the data.
#
# Dataset has 200 customers with 5 columns.
#
# Four columns are numeric, one is categorical (Genre).
#
# Age, Income, and Spending Score have clean, valid values.
#
# Dataset is small and easy to work with for analysis

# %% [markdown]
# ## 6.Analysis with Numpy and Pandas

# %%
import numpy as np
import pandas as pd

# Assuming df is already loaded and cleaned, with renamed columns

# Average Age of Customers
avg_age = np.mean(df['Age'])
print("Average Age:", round(avg_age, 2))

# Average Annual Income
avg_income = np.mean(df['Annual_Income'])
print("Average Annual Income (k$):", round(avg_income, 2))

# Average Spending Score
avg_spending = np.mean(df['Spending_Score'])
print("Average Spending Score:", round(avg_spending, 2))

# Average Spending Score by Genre
spending_by_genre = df.groupby('Genre')['Spending_Score'].mean()
print("\nAverage Spending Score by Genre:")
print(spending_by_genre)

# Average Annual Income by Genre
income_by_genre = df.groupby('Genre')['Annual_Income'].mean()
print("\nAverage Annual Income (k$) by Genre:")
print(income_by_genre)
# Out:
# Average Age: 38.85
# Average Annual Income (k$): 60.56
# Average Spending Score: 50.2
#
# Average Spending Score by Genre:
# Genre
# Female    51.526786
# Male      48.511364
# Name: Spending_Score, dtype: float64
#
# Average Annual Income (k$) by Genre:
# Genre
# Female    59.250000
# Male      62.227273
# Name: Annual_Income, dtype: float64

# %% [markdown]
# #### Insights
# The average customer is about 39 years old.
#
# Average annual income is around $60.56k.
#
# The average spending score is 50.2, showing moderate spending habits.
#
# Female customers tend to have a slightly higher average spending score than males.
#
# Male customers have a slightly higher average annual income than females.

# %% [markdown]
# ## 7.Visualization with Matplotlib

# %%
import matplotlib.pyplot as plt

# Data
genres = ['Female', 'Male']
avg_spending = [51.53, 48.51]
avg_income = [59.25, 62.23]

plt.figure(figsize=(12, 5))

# Bar Chart: Average Spending Score by Genre
plt.subplot(1, 2, 1)
plt.bar(genres, avg_spending, color=['pink', 'blue'])
plt.title('Average Spending Score by Genre')
plt.xlabel('Genre')
plt.ylabel('Spending Score')
plt.ylim(0, 100)

# Line Plot: Average Annual Income by Genre
plt.subplot(1, 2, 2)
plt.plot(genres, avg_income, marker='o', color='green', linestyle='-', linewidth=2)
plt.title('Average Annual Income (k$) by Genre')
plt.xlabel('Genre')
plt.ylabel('Annual Income (k$)')
plt.ylim(0, 100)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insights:
# Females spend more on average than males.
#
# Males have higher average annual income.
#
# Spending habits differ by gender despite income differences.
#
# Both genders show moderate spending scores overall.

# %% [markdown]
# ## 8.Visualization with Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Seaborn style
sns.set(style="whitegrid")

# 1. Histogram: Distribution of Annual Income
plt.figure(figsize=(8, 5))
sns.histplot(df['Annual_Income'], bins=15, kde=True, color='teal')
plt.title('Annual Income Distribution')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Count')
plt.show()

# 2. Heatmap: Correlation matrix
plt.figure(figsize=(8, 5))
corr = df[['Age', 'Annual_Income', 'Spending_Score']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# 3. Boxplot: Spending Score by Genre
plt.figure(figsize=(8, 5))
sns.boxplot(x='Genre', y='Spending_Score', data=df, palette='pastel')
plt.title('Spending Score by Gender')
plt.show()

# 4. Pairplot: Relationships between Age, Income, and Spending
sns.pairplot(df[['Age', 'Annual_Income', 'Spending_Score']], diag_kind='kde')
plt.suptitle('Pairplot of Key Numerical Features', y=1.02)
plt.show()
# Out:
# C:\Users\chund\AppData\Local\Temp\ipykernel_23428\4051868946.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Genre', y='Spending_Score', data=df, palette='pastel')

# %% [markdown]
# #### Insights:
# 1. Histogram – Annual Income Distribution
#
# Most customers earn between $40k and $80k per year.
#
# The distribution is fairly uniform, with no strong skew.
#
# A few customers earn very low (<$30k) or very high (>$100k) incomes, indicating a wide income range.
#
#  2. Heatmap – Correlation Matrix
#
# Spending Score and Annual Income have no strong correlation (near 0).
#
# Age and Spending Score show a slightly negative correlation, suggesting older customers may spend less.
#
# Age and Income have a weak positive correlation, meaning older customers tend to earn a bit more.
#
# 3. Boxplot – Spending Score by Gender
#
# Female customers have a higher median spending score than males.
#
# The spread (IQR) for both genders is wide, showing diverse spending behavior.
#
# Some outliers exist, especially for high spenders in both groups.
#
#  4. Pairplot – Age, Income, and Spending Score
#
# No strong linear relationship between any pair of features.
#
# Younger customers show a wider range of spending scores, from low to very high.
#
# Customers with moderate income (40k–80k) are scattered across all spending score levels.

# %% [markdown]
# # EDA

# %%
#Univariate Analysis - Numerical Features
num_cols = df.select_dtypes(include=['int64','float64']).columns
df[num_cols].describe()

# Histogram: Age
sns.histplot(df['Age'], bins=20, kde=True, color='skyblue')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# Boxplot: Annual Income
sns.boxplot(x=df['Annual Income (k$)'], color='orange')
plt.title("Boxplot - Annual Income")
plt.xlabel("Annual Income (k$)")
plt.show()

# %%
#Univariate Analysis - Categorical Features
cat_cols = df.select_dtypes(include=['object']).columns

for col in cat_cols:
    sns.countplot(x=col, data=df, palette='Set2')
    plt.title(f"Count of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()
# Out:
# C:\Users\chund\AppData\Local\Temp\ipykernel_16024\245898718.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, palette='Set2')

# %%
#Bivariate Analysis - Numerical vs Categorical
# Boxplot: Age by Genre
sns.boxplot(x='Genre', y='Age', data=df, palette='Set3')
plt.title("Age by Gender")
plt.show()

# Boxplot: Spending Score by Genre
sns.boxplot(x='Genre', y='Spending Score (1-100)', data=df, palette='Set2')
plt.title("Spending Score by Gender")
plt.show()
# Out:
# C:\Users\chund\AppData\Local\Temp\ipykernel_16024\3627561772.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Genre', y='Age', data=df, palette='Set3')
# C:\Users\chund\AppData\Local\Temp\ipykernel_16024\3627561772.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Genre', y='Spending Score (1-100)', data=df, palette='Set2')

# %%
#Bivariate Analysis - Categorical vs Categorical
# Create a new categorical feature: Age group
df['Age_Group'] = pd.cut(df['Age'], bins=[0, 25, 40, 60], labels=['Young', 'Adult', 'Senior'])

sns.countplot(x='Genre', hue='Age_Group', data=df, palette='Set2')
plt.title("Gender vs Age Group")
plt.show()

# %%
#Correlation and Multivariate Analysis
# Correlation Heatmap (numeric columns only)
numeric_cols = df.select_dtypes(include=['int64','float64']).columns
corr = df[numeric_cols].corr()

sns.heatmap(corr, cmap='coolwarm', annot=True)
plt.title("Correlation Heatmap - Mall Customer Dataset")
plt.show()

# %%
#Outlier Detection using IQR
# Example on Spending Score
Q1 = df['Spending Score (1-100)'].quantile(0.25)
Q3 = df['Spending Score (1-100)'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df['Spending Score (1-100)'] < lower) | (df['Spending Score (1-100)'] > upper)]
print("Number of outliers in Spending Score:", len(outliers))

df['SpendingScore_Capped'] = df['Spending Score (1-100)'].clip(lower, upper)

sns.boxplot(x=df['SpendingScore_Capped'], color='lightgreen')
plt.title("Spending Score after Outlier Capping")
plt.show()
# Out:
# Number of outliers in Spending Score: 0

# %%
#Feature Engineering
# Example: create a feature for Income Category
df['Income_Category'] = pd.cut(df['Annual Income (k$)'], bins=[0, 40, 70, 120], labels=['Low', 'Medium', 'High'])

# Example: create a feature for Spending Level
df['Spending_Level'] = pd.cut(df['SpendingScore_Capped'], bins=[0, 33, 66, 100], labels=['Low', 'Medium', 'High'])

sns.countplot(x='Income_Category', hue='Spending_Level', data=df, palette='Set2')
plt.title("Income Category vs Spending Level")
plt.show()

df[['Annual Income (k$)', 'SpendingScore_Capped', 'Income_Category', 'Spending_Level']].head()
# Out:
#    Annual Income (k$)  SpendingScore_Capped Income_Category Spending_Level
# 0                  15                    39             Low         Medium
# 1                  15                    81             Low           High
# 2                  16                     6             Low            Low
# 3                  16                    77             Low           High
# 4                  17                    40             Low         Medium

# %%
#Export the Cleaned Data
df.to_csv("MallCustomers_Cleaned.csv", index=False)
print("\nCleaned Mall Customer Data saved as MallCustomers_Cleaned.csv")
# Out:
# Cleaned Mall Customer Data saved as MallCustomers_Cleaned.csv
